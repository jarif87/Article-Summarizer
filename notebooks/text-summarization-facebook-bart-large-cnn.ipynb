# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import string
import numpy as np
from PIL import Image
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import nltk
from wordcloud import WordCloud, STOPWORDS
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wordcloud_mask=np.array(Image.open("/kaggle/input/word-cloud-5/stormtrooper_mask.png"))

# %%
df=pd.read_csv("/kaggle/input/article/article_highlights.csv")

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.dailymail.co.uk/tvshowbiz/article-...
# 1  https://www.dailymail.co.uk/tvshowbiz/article-...
# 2  https://www.dailymail.co.uk/tvshowbiz/article-...
# 3  https://www.dailymail.co.uk/tvshowbiz/article-...
# 4  https://www.dailymail.co.uk/tvshowbiz/article-...
#
#                                              article  \
# 0  Beyoncé showcases her incredible figure in plu...
# 1  Radio 1 listeners in shock as sex noises are p...
# 2  TOWIE's Dan Edgar, 33, and Ella Rae Wise, 23, ...
# 3  Bradley Cooper recalls 'crazy' pitch meeting a...
# 4  Margaret Qualley and Beanie Feldstein stun in ...
#
#                                           highlights
# 0  Beyoncé has shown off her flawless beauty in a...
# 1  BBC Radio 1 listeners were left choking on the...
# 2  Dan Edgar and Ella Rae Wise put on a loved-up ...
# 3  Bradley Cooper discussed the 'crazy' experienc...
# 4  Margaret Qualley and Beanie Feldstein were dre...

# %%
df.drop(columns="url",axis=1,inplace=True)

# %%
df = df.astype(str)

# %%
df.head()
# Out:
#                                              article  \
# 0  Beyoncé showcases her incredible figure in plu...
# 1  Radio 1 listeners in shock as sex noises are p...
# 2  TOWIE's Dan Edgar, 33, and Ella Rae Wise, 23, ...
# 3  Bradley Cooper recalls 'crazy' pitch meeting a...
# 4  Margaret Qualley and Beanie Feldstein stun in ...
#
#                                           highlights
# 0  Beyoncé has shown off her flawless beauty in a...
# 1  BBC Radio 1 listeners were left choking on the...
# 2  Dan Edgar and Ella Rae Wise put on a loved-up ...
# 3  Bradley Cooper discussed the 'crazy' experienc...
# 4  Margaret Qualley and Beanie Feldstein were dre...

# %%
df.shape
# Out:
# (8176, 2)

# %%
df.isnull().sum()
# Out:
# article       0
# highlights    0
# dtype: int64

# %%
def clean_text(text):
    if isinstance(text, str):
        # Remove HTML tags
        text = BeautifulSoup(text, 'html.parser').get_text()

        # Remove special characters and digits
        text = re.sub(r"[^a-zA-Z]", " ", text)

        # Remove punctuation
        text = text.translate(str.maketrans("", "", string.punctuation))

        # Remove emojis
        emoji_pattern = re.compile("["
                                   u"\U0001F600-\U0001F64F"  # emoticons
                                   u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                                   u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                   u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                   u"\U00002702-\U000027B0"
                                   u"\U000024C2-\U0001F251"
                                   "]+", flags=re.UNICODE)
        text = emoji_pattern.sub(r'', text)

        # Convert to lowercase
        text = text.lower()

        # Remove stop words
        stop_words = set(stopwords.words('english'))
        tokens = word_tokenize(text)
        tokens = [word for word in tokens if word not in stop_words]
        text = ' '.join(tokens)

        return text
    else:
        # If the text is not a string (NaN or other), return an empty string
        return ""

# %%
df["clean_article"]=df["article"].apply(clean_text)

# %%
df["clean_highlights"]=df['highlights'].apply(clean_text)

# %%
df.head()
# Out:
#                                              article  \
# 0  Beyoncé showcases her incredible figure in plu...
# 1  Radio 1 listeners in shock as sex noises are p...
# 2  TOWIE's Dan Edgar, 33, and Ella Rae Wise, 23, ...
# 3  Bradley Cooper recalls 'crazy' pitch meeting a...
# 4  Margaret Qualley and Beanie Feldstein stun in ...
#
#                                           highlights  \
# 0  Beyoncé has shown off her flawless beauty in a...
# 1  BBC Radio 1 listeners were left choking on the...
# 2  Dan Edgar and Ella Rae Wise put on a loved-up ...
# 3  Bradley Cooper discussed the 'crazy' experienc...
# 4  Margaret Qualley and Beanie Feldstein were dre...
#
#                                        clean_article  \
# 0  beyonc showcases incredible figure plunging wh...
# 1  radio listeners shock sex noises played greg j...
# 2  towie dan edgar ella rae wise put loved displa...
# 3  bradley cooper recalls crazy pitch meeting bey...
# 4  margaret qualley beanie feldstein stun chic fl...
#
#                                     clean_highlights
# 0  beyonc shown flawless beauty new photo promote...
# 1  bbc radio listeners left choking cornflakes we...
# 2  dan edgar ella rae wise put loved display sun ...
# 3  bradley cooper discussed crazy experience meet...
# 4  margaret qualley beanie feldstein dressed nine...

# %%
plt.figure(figsize=(15,15))
all_text=" ".join(df['clean_article'].values.tolist())
wordcloud = WordCloud(width=800, height=800,stopwords=STOPWORDS, background_color='black', max_words=800,colormap="jet",mask=wordcloud_mask).generate(all_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(15,15))
all_text=" ".join(df['clean_highlights'].values.tolist())
wordcloud = WordCloud(width=800, height=800,stopwords=STOPWORDS, background_color='black', max_words=800,colormap="hsv",mask=wordcloud_mask).generate(all_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from itertools import chain
from collections import Counter
import seaborn as sns

# %%
data_set =df["clean_article"].str.split()
all_words = list(chain.from_iterable(data_set))
counter = Counter(all_words)
common_words = counter.most_common(30)
df_common_words = pd.DataFrame(common_words, columns=['Word', 'Count'])

colors = ["cyan", "lime", "magenta", "gold", "purple", "tomato", "teal", "sandybrown", "mediumseagreen",
          "royalblue", "darkorchid", "darkturquoise", "darkgoldenrod", "mediumvioletred", "mediumaquamarine",
          "lightcoral", "darkslategray", "olivedrab", "dodgerblue", "indianred", "limegreen", "steelblue",
          "darkviolet", "chocolate", "mediumslateblue", "darkgreen", "orangered", "mediumblue", "peru", "mediumspringgreen"]

plt.figure(figsize=(12, 6))
sns.barplot(x='Count', y='Word', data=df_common_words, palette=colors)
plt.title('30 Most Common Words')
plt.xlabel('Count')
plt.ylabel('Word')
plt.show()

# %%
data_set =df["clean_highlights"].str.split()
all_words = list(chain.from_iterable(data_set))
counter = Counter(all_words)
common_words = counter.most_common(30)
df_common_words = pd.DataFrame(common_words, columns=['Word', 'Count'])

colors = ["cyan", "lime", "magenta", "gold", "purple", "tomato", "teal", "sandybrown", "mediumseagreen",
          "royalblue", "darkorchid", "darkturquoise", "darkgoldenrod", "mediumvioletred", "mediumaquamarine",
          "lightcoral", "darkslategray", "olivedrab", "dodgerblue", "indianred", "limegreen", "steelblue",
          "darkviolet", "chocolate", "mediumslateblue", "darkgreen", "orangered", "mediumblue", "peru", "mediumspringgreen"]

plt.figure(figsize=(12, 6))
sns.barplot(x='Count', y='Word', data=df_common_words, palette=colors)
plt.title('30 Most Common Words')
plt.xlabel('Count')
plt.ylabel('Word')
plt.show()

# %%
# !pip install transformers -Uqq

# !pip install bert-score -Uqq
# !pip install sacremoses
# !pip install ohmeow-blurr -Uqq
# Out:
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacremoses) (2023.12.25)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sacremoses) (4.66.1)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 14.1 MB/s eta 0:00:00 0:00:01
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.7.1 requires torch>=2, but you have torch 1.13.1 which is incompatible.

# %%
# !pip install git+https://github.com/ohmeow/blurr.git
# Out:
# Collecting git+https://github.com/ohmeow/blurr.git
#   Cloning https://github.com/ohmeow/blurr.git to /tmp/pip-req-build-ksd1l1pr
#   Running command git clone --filter=blob:none --quiet https://github.com/ohmeow/blurr.git /tmp/pip-req-build-ksd1l1pr
#   Resolved https://github.com/ohmeow/blurr.git to commit 8e20e65037425283d3d27f7065462a0a73da91c3
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch<2.0.0,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (1.13.1)
# Requirement already satisfied: fastcore>=1.5 in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (1.5.29)
# Requirement already satisfied: fastai>=2.5 in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (2.7.13)
# Requirement already satisfied: transformers>=4.6 in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (4.38.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (2.1.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (0.1.99)
# Requirement already satisfied: seqeval in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (1.2.2)
# Requirement already satisfied: rouge-score in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (0.1.2)
# Requirement already satisfied: openpyxl<4.0,>=3.0.7 in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (3.1.2)
# Requirement already satisfied: xlrd<3.0,>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from blurr==1.0.6) (2.0.1)
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (23.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (21.3)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (0.0.7)
# Requirement already satisfied: torchvision>=0.11 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (0.16.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (3.7.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (2.1.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (2.31.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (9.5.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (1.11.4)
# Requirement already satisfied: spacy<4 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.5->blurr==1.0.6) (3.7.2)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from openpyxl<4.0,>=3.0.7->blurr==1.0.6) (1.1.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch<2.0.0,>=1.7.0->blurr==1.0.6) (4.9.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch<2.0.0,>=1.7.0->blurr==1.0.6) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.10/site-packages (from torch<2.0.0,>=1.7.0->blurr==1.0.6) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.10/site-packages (from torch<2.0.0,>=1.7.0->blurr==1.0.6) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.10/site-packages (from torch<2.0.0,>=1.7.0->blurr==1.0.6) (11.7.99)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.7.0->blurr==1.0.6) (69.0.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.7.0->blurr==1.0.6) (0.42.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (1.24.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (0.15.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.6->blurr==1.0.6) (4.66.1)
# Requirement already satisfied: pyarrow>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->blurr==1.0.6) (11.0.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from datasets->blurr==1.0.6) (0.3.7)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->blurr==1.0.6) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->blurr==1.0.6) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->datasets->blurr==1.0.6) (2023.12.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->blurr==1.0.6) (3.9.1)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets->blurr==1.0.6) (0.18.0)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score->blurr==1.0.6) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge-score->blurr==1.0.6) (3.2.4)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge-score->blurr==1.0.6) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->blurr==1.0.6) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->blurr==1.0.6) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->blurr==1.0.6) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->blurr==1.0.6) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->blurr==1.0.6) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->blurr==1.0.6) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fastai>=2.5->blurr==1.0.6) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.5->blurr==1.0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.5->blurr==1.0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.5->blurr==1.0.6) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.5->blurr==1.0.6) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fastai>=2.5->blurr==1.0.6) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fastai>=2.5->blurr==1.0.6) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (2.5.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.5->blurr==1.0.6) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.5->blurr==1.0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.5->blurr==1.0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.5->blurr==1.0.6) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.5->blurr==1.0.6) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.5->blurr==1.0.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fastai>=2.5->blurr==1.0.6) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fastai>=2.5->blurr==1.0.6) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.5->blurr==1.0.6) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.5->blurr==1.0.6) (2.14.6)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.5->blurr==1.0.6) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.5->blurr==1.0.6) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai>=2.5->blurr==1.0.6) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai>=2.5->blurr==1.0.6) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<4->fastai>=2.5->blurr==1.0.6) (2.1.3)
# Building wheels for collected packages: blurr
#   Building wheel for blurr (setup.py) ... done
#   Created wheel for blurr: filename=blurr-1.0.6-py3-none-any.whl size=86459 sha256=cbed10711633f58617487ef66efa271bb70ec00d391a494f7ede7c592eb0e433
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2p0bv3c1/wheels/a6/7a/bf/bcc6241908f88454eadbb8d864bb4c26df0e8ed86e8b253082
# Successfully built blurr
# Installing collected packages: blurr
# Successfully installed blurr-1.0.6

# %%
import torch
from fastai.text.all import *
from blurr.text.data.all import *
from blurr.text.modeling.all import *
# Out:
# 2024-02-27 13:21:25.595398: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-27 13:21:25.595517: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-27 13:21:25.729764: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Downloading builder script:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.12k [00:00<?, ?B/s]

# %%
from transformers import BartForConditionalGeneration

# %%
pretrained_model_name = "facebook/bart-large-cnn"
hf_arch, hf_config, hf_tokenizer, hf_model = get_hf_objects(pretrained_model_name,model_cls=BartForConditionalGeneration)

hf_arch, type(hf_config), type(hf_tokenizer), type(hf_model)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# ('bart',
#  transformers.models.bart.configuration_bart.BartConfig,
#  transformers.models.bart.tokenization_bart_fast.BartTokenizerFast,
#  transformers.models.bart.modeling_bart.BartForConditionalGeneration)

# %%
import transformers

print(transformers.__version__)
# Out:
# 4.38.1

# %%
text_gen_kwargs = default_text_gen_kwargs(hf_config, hf_model, task='summarization')
text_gen_kwargs
# Out:
# {'early_stopping': True,
#  'length_penalty': 2.0,
#  'max_length': 142,
#  'min_length': 56,
#  'no_repeat_ngram_size': 3,
#  'num_beams': 4}

# %%
hf_batch_tfm = Seq2SeqBatchTokenizeTransform(hf_arch, hf_config, hf_tokenizer, hf_model, max_length=256, max_tgt_length=130, text_gen_kwargs=text_gen_kwargs)
blocks = (Seq2SeqTextBlock(batch_tokenize_tfm=hf_batch_tfm), noop)
dblock = DataBlock(blocks=blocks, get_x=ColReader('article'), get_y=ColReader('highlights'), splitter=RandomSplitter())

# %%
dls = dblock.dataloaders(df, bs=16)

# %%
len(dls.train.items), len(dls.valid.items)
# Out:
# (6541, 1635)

# %%
dls.show_batch(dataloaders=dls, max_n=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>&lt;s&gt; Liverpool 4-1 Luton Town: Injury-ravaged Reds score FOUR second-half goals as they come from behind to move clear at the top of the Premier League There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.&lt;/s&gt;</td>
#       <td>There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>&lt;s&gt; Liverpool 4-1 Luton Town: Injury-ravaged Reds score FOUR second-half goals as they come from behind to move clear at the top of the Premier League There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.&lt;/s&gt;</td>
#       <td>There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>&lt;s&gt; Liverpool 4-1 Luton Town: Injury-ravaged Reds score FOUR second-half goals as they come from behind to move clear at the top of the Premier League There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.&lt;/s&gt;</td>
#       <td>There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>&lt;s&gt; Liverpool 4-1 Luton Town: Injury-ravaged Reds score FOUR second-half goals as they come from behind to move clear at the top of the Premier League There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.&lt;/s&gt;</td>
#       <td>There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>&lt;s&gt; Liverpool 4-1 Luton Town: Injury-ravaged Reds score FOUR second-half goals as they come from behind to move clear at the top of the Premier League There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.&lt;/s&gt;</td>
#       <td>There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#     </tr>
#   </tbody>
# </table>

# %%
seq2seq_metrics = {
        'rouge': {
            'compute_kwargs': { 'rouge_types': ["rouge1", "rouge2", "rougeL"], 'use_stemmer': True },
            'returns': ["rouge1", "rouge2", "rougeL"]
        },
        'bertscore': {
            'compute_kwargs': { 'lang': 'en' },
            'returns': ["precision", "recall", "f1"]
        }
    }

# %%
model = BaseModelWrapper(hf_model)
learn_cbs = [BaseModelCallback]


fit_cbs = [Seq2SeqMetricsCallback(custom_metrics=seq2seq_metrics)]


learn = Learner(dls,
                model,
                opt_func=partial(Adam, decouple_wd=True),
                loss_func=CrossEntropyLossFlat(),
                metrics=[accuracy],
                cbs=learn_cbs,
                splitter=partial(blurr_seq2seq_splitter, arch=hf_arch)).to_fp16()
# Out:
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.92k [00:00<?, ?B/s]

# %%
learn.create_opt()

# %%
learn.freeze()

# %%
learn.lr_find(suggest_funcs=[slide, valley])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# SuggestedLRs(slide=1.2022644114040304e-05, valley=1.2022644114040304e-05)

# %%
learn.fit_one_cycle(5,lr_max=3e-5, cbs=fit_cbs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>rouge1</th>
#       <th>rouge2</th>
#       <th>rougeL</th>
#       <th>bertscore_precision</th>
#       <th>bertscore_recall</th>
#       <th>bertscore_f1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.034950</td>
#       <td>0.243474</td>
#       <td>0.906524</td>
#       <td>0.641891</td>
#       <td>0.629694</td>
#       <td>0.639667</td>
#       <td>0.909267</td>
#       <td>0.978228</td>
#       <td>0.942274</td>
#       <td>06:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.013044</td>
#       <td>0.101433</td>
#       <td>0.908225</td>
#       <td>0.642299</td>
#       <td>0.631273</td>
#       <td>0.642238</td>
#       <td>0.906246</td>
#       <td>0.977613</td>
#       <td>0.940286</td>
#       <td>06:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003856</td>
#       <td>0.151606</td>
#       <td>0.908436</td>
#       <td>0.591151</td>
#       <td>0.579684</td>
#       <td>0.588466</td>
#       <td>0.891680</td>
#       <td>0.978395</td>
#       <td>0.932596</td>
#       <td>07:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001553</td>
#       <td>0.110650</td>
#       <td>0.908587</td>
#       <td>0.603654</td>
#       <td>0.591245</td>
#       <td>0.603010</td>
#       <td>0.892740</td>
#       <td>0.977935</td>
#       <td>0.933083</td>
#       <td>06:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001742</td>
#       <td>0.098103</td>
#       <td>0.908587</td>
#       <td>0.595496</td>
#       <td>0.583506</td>
#       <td>0.595084</td>
#       <td>0.890820</td>
#       <td>0.976531</td>
#       <td>0.931403</td>
#       <td>06:51</td>
#     </tr>
#   </tbody>
# </table>
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
learn.show_results(learner=learn, max_n=2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>target</th>
#       <th>prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Liverpool 4-1 Luton Town: Injury-ravaged Reds score FOUR second-half goals as they come from behind to move clear at the top of the Premier League There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#       <td>There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.</td>
#       <td>[ There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was one word on the lips of all Liverpool fans at the start of last night: injuries. One fan had posted a clever edit of the Reds logo on social media before the match, adding bandaging to the legs of the famous Liver Bird, denoting a crisis of 10 crocked first-team players.,  There was on ...
#     </tr>
#   </tbody>
# </table>

# %%
test_article="Pippa Middleton showed off her toned physique in a blue gingham one-piece during a day at the beach in St Barts with her husband and children.The mother-of-three, 40, wore tblue-and-white patterned swimsuit for her day out on Gouverneur beach, near the £90m estate of Russian oligarch Roman Abramovich.ippa, her husband James Matthews and their three children have spent weeks enjoying the winter sun at Eden Rock Beach, which is owned by James' family.However, they appeared to venture further afield for one of their final beach days on the Caribbean island before heading home to their £15m Berkshire mansion.During the family getaway, the Princess of Wales' younger sister has worn over £2,000 worth of designer swimwear and accessories. "

# %%
outputs = learn.blurr_summarize(test_article, early_stopping=True, num_beams=4, num_return_sequences=3)

for idx, o in enumerate(outputs):
    print(f'=== Prediction {idx+1} ===\n{o}\n')
# Out:
# === Prediction 1 ===
# {'summary_texts': [" Pippa Middleton wore tblue-and-white patterned swimsuit for her day out on Gouverneur beach, near the £90m estate of Russian oligarch Roman Abramovich.During the family getaway, the Princess of Wales' younger sister has worn over £2,000 worth of designer swimwear and accessories. ", " Pippa Middleton wore tblue-and-white patterned swimsuit for her day out on Gouverneur beach, near the £90m estate of Russian oligarch Roman Abramovich.During the family getaway, the Princess of Wales' younger sister has worn over £2,000 worth of designer swimwear and accessories. ", " Pippa Middleton wore tblue-and-white patterned swimsuit for her day out on Gouverneur beach, near the £90m estate of Russian oligarch Roman Abramovich.During the family getaway, the Princess of Wales' younger sister has worn over £2,000 worth of designer swimwear and accessories."]}

# %%
learn.metrics = None
learn.export('models/article_highlights_part3.pkl')

# %%
inf_learn = load_learner(fname='models/article_highlights_part3.pkl')
inf_learn.blurr_summarize(test_article)
# Out:
# [{'summary_texts': " Pippa Middleton wore tblue-and-white patterned swimsuit for her day out on Gouverneur beach, near the £90m estate of Russian oligarch Roman Abramovich.During the family getaway, the Princess of Wales' younger sister has worn over £2,000 worth of designer swimwear and accessories. "}]

# %%
! pip show ohmeow-blurr
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Name: ohmeow-blurr
# Version: 1.0.5
# Summary: A library designed for fastai developers who want to train and deploy Hugging Face transformers
# Home-page: https://github.com/ohmeow/blurr/tree/master/
# Author: Wayde Gilliam
# Author-email: wgilliam@ohmeow.com
# License: Apache Software License 2.0
# Location: /opt/conda/lib/python3.10/site-packages
# Requires: datasets, fastai, fastcore, openpyxl, rouge-score, sentencepiece, seqeval, torch, transformers, xlrd
# Required-by:
